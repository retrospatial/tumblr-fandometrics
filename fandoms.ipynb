# %% [markdown]
# # Ship and Let Ship: A Brief Analysis of Shipping Trends on Tumblr

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from itertools import islice
import csv

# %% [markdown]
# ## static test

# %%
link = "https://fanlore.org/wiki/Tumblr_Fandometrics%27_Year_in_Review_2014"
response = requests.get(link)
html = response.text

soup = BeautifulSoup(html)

# find every element under 'Most Reblogged Ships'
ship_list = soup.find('span', id='Most_Reblogged_Ships').find_next('ol')

# %%
ship_string = ship_list.select('li')[0].text

# %%
# full element
# Destiel - Dean Winchester & Castiel, Supernatural
ship_string = ship_list.select('li')[0].text

# first split
# ['Destiel', 'Dean Winchester & Castiel, Supernatural']
ship_parts = ship_string.split(' - ')

# ship name
# Destiel
ship_name = ship_parts[0]

# characters
# character1: Dean Winchester
# character2: Castiel
character_string = ship_parts[1].split(', ')
characters_all = character_string[0].split(' & ')
character1 = characters_all[0]
character2 = characters_all[1]

# show
# Supernatural
show = character_string[1]

ship_dict = {
    'name': ship_name,
    'character1': character1,
    'character2': character2,
    'show': show
}

print(ship_dict)
# Out:
# {'name': 'Destiel', 'character1': 'Dean Winchester', 'character2': 'Castiel', 'show': 'Supernatural'}

# %% [markdown]
# ### print all the ship info from 2014

# %%
ship_list = soup.find('span', id='Most_Reblogged_Ships').find_next('ol')

ships = []

# enumerate starting from 1
for index, ship in enumerate(ship_list.select('li'), 1):
    ship_string = ship.text

    ship_parts = re.split(r' - | -', ship_string)

    name = ship_parts[0]

    character_string = ship_parts[1].split(', ')
    characters_all = character_string[0].split(' & ')
    character1 = characters_all[0]
    character2 = characters_all[1]

    show = character_string[1]

    year = link[-4:]

    ship_info = {
        'year': year,
        'rank': index,
        'name': name,
        'character 1': character1,
        'character 2': character2,
        'show': show,
    }

    ships.append(ship_info)

ships
# Out:
# [{'year': '2014',
#   'rank': 1,
#   'name': 'Destiel',
#   'character 1': 'Dean Winchester',
#   'character 2': 'Castiel',
#   'show': 'Supernatural'},
#  {'year': '2014',
#   'rank': 2,
#   'name': 'Johnlock',
#   'character 1': 'John Watson',
#   'character 2': 'Sherlock Holmes',
#   'show': 'Sherlock'},
#  {'year': '2014',
#   'rank': 3,
#   'name': 'Larry Stylinson',
#   'character 1': 'Harry Styles',
#   'character 2': 'Louis Tomlinson',
#   'show': 'One Direction'},
#  {'year': '2014',
#   'rank': 4,
#   'name': 'Captain Swan',
#   'character 1': 'Captain Hook',
#   'character 2': 'Emma Swan',
#   'show': 'Once Upon a Time'},
#  {'year': '2014',
#   'rank': 5,
#   'name': 'Ereri',
#   'character 1': 'Eren Jaeger',
#   'character 2': 'Levi Ackerman',
#   'show': 'Attack on Titan'},
#  {'year': '2014',
#   'rank': 6,
#   'name': 'Sterek',
#   'character 1': 'Stiles Stilinski',
#   'character 2': 'Derek Hale',
#   'show': 'Teen Wolf'},
#  {'year': '2014',
#   'rank': 7,
#   'name': 'Troyler',
#   'character 1': 'Troye Sivan',
#   'character 2': 'Tyler Oakley',
#   'show': 'YouTubers'},
#  {'year': '2014',
#   'rank': 8,
#   'name': 'MakoHaru',
#   'character 1': 'Makoto Tachibana',
#   'character 2': 'Haruka Nanase',
#   'show': 'Free!'},
#  {'year': '2014',
#   'rank': 9,
#   'name': 'Narry',
#   'character 1': 'Harry Styles',
#   'character 2': 'Niall Horan',
#   'show': 'One Direction'},
#  {'year': '2014',
#   'rank': 10,
#   'name': 'JeanMarco',
#   'character 1': 'Jean Kirstein',
#   'character 2': 'Marco Bott',
#   'show': 'Attack on Titan'},
#  {'year': '2014',
#   'rank': 11,
#   'name': 'HaruRin',
#   'character 1': 'Haruka Nanase',
#   'character 2': 'Rin Matsuoka',
#   'show': 'Free!'},
#  {'year': '2014',
#   'rank': 12,
#   'name': 'Delena',
#   'character 1': 'Damon Salvatore',
#   'character 2': 'Elena Gilbert',
#   'show': 'The Vampire Diaries'},
#  {'year': '2014',
#   'rank': 13,
#   'name': 'Stydia',
#   'character 1': 'Stiles Stilinski',
#   'character 2': 'Lydia Martin',
#   'show': 'Teen Wolf'},
#  {'year': '2014',
#   'rank': 14,
#   'name': 'Klaine',
#   'character 1': 'Kurt Hummel',
#   'character 2': 'Blaine Anderson',
#   'show': ' Glee'},
#  {'year': '2014',
#   'rank': 15,
#   'name': 'Ziam',
#   'character 1': 'Zayn Malik',
#   'character 2': 'Liam Payne',
#   'show': 'One Direction'},
#  {'year': '2014',
#   'rank': 16,
#   'name': 'Kimye',
#   'character 1': 'Kim Kardashian',
#   'character 2': 'Kanye West',
#   'show': 'America’s Sweethearts'},
#  {'year': '2014',
#   'rank': 17,
#   'name': 'Stucky',
#   'character 1': 'Steve Rogers',
#   'character 2': 'Bucky Barnes',
#   'show': 'Captain America: The Winter Soldier'},
#  {'year': '2014',
#   'rank': 18,
#   'name': 'Olicity',
#   'character 1': 'Oliver Queen',
#   'character 2': 'Felicity Smoak',
#   'show': 'Arrow'},
#  {'year': '2014',
#   'rank': 19,
#   'name': 'Dan and Phil',
#   'character 1': 'danisnotonfire',
#   'character 2': 'AmazingPhil',
#   'show': 'YouTubers'},
#  {'year': '2014',
#   'rank': 20,
#   'name': 'Swan Queen',
#   'character 1': 'Regina Mills',
#   'character 2': 'Emma Swan',
#   'show': 'Once Upon a Time'}]

# %%
df = pd.DataFrame(ships)
df
# Out:
#     year  rank             name       character 1      character 2  \
# 0   2014     1          Destiel   Dean Winchester          Castiel
# 1   2014     2         Johnlock       John Watson  Sherlock Holmes
# 2   2014     3  Larry Stylinson      Harry Styles  Louis Tomlinson
# 3   2014     4     Captain Swan      Captain Hook        Emma Swan
# 4   2014     5            Ereri       Eren Jaeger    Levi Ackerman
# 5   2014     6           Sterek  Stiles Stilinski       Derek Hale
# 6   2014     7          Troyler       Troye Sivan     Tyler Oakley
# 7   2014     8         MakoHaru  Makoto Tachibana    Haruka Nanase
# 8   2014     9            Narry      Harry Styles      Niall Horan
# 9   2014    10        JeanMarco     Jean Kirstein       Marco Bott
# 10  2014    11          HaruRin     Haruka Nanase     Rin Matsuoka
# 11  2014    12           Delena   Damon Salvatore    Elena Gilbert
# 12  2014    13           Stydia  Stiles Stilinski     Lydia Martin
# 13  2014    14           Klaine       Kurt Hummel  Blaine Anderson
# 14  2014    15             Ziam        Zayn Malik       Liam Payne
# 15  2014    16            Kimye    Kim Kardashian       Kanye West
# 16  2014    17           Stucky      Steve Rogers     Bucky Barnes
# 17  2014    18          Olicity      Oliver Queen   Felicity Smoak
# 18  2014    19     Dan and Phil    danisnotonfire      AmazingPhil
# 19  2014    20       Swan Queen      Regina Mills        Emma Swan
#
#                                    show
# 0                          Supernatural
# 1                              Sherlock
# 2                         One Direction
# 3                      Once Upon a Time
# 4                       Attack on Titan
# 5                             Teen Wolf
# 6                             YouTubers
# 7                                 Free!
# 8                         One Direction
# 9                       Attack on Titan
# 10                                Free!
# 11                  The Vampire Diaries
# 12                            Teen Wolf
# 13                                 Glee
# 14                        One Direction
# 15                America’s Sweethearts
# 16  Captain America: The Winter Soldier
# 17                                Arrow
# 18                            YouTubers
# 19                     Once Upon a Time

# %% [markdown]
# # now try do a for loop for each year 2014-2020 (reminder 2021 & 2022 not counted)

# %%
years = [2014, 2015]
all_ships = []

for year in years:
    link = f"https://fanlore.org/wiki/Tumblr_Fandometrics%27_Year_in_Review_{year}"
    response = requests.get(link)
    html = response.text

    soup = BeautifulSoup(html)

    ship_list = soup.find('span', id='Most_Reblogged_Ships').find_next('ol')

    ships = []

    # enumerate starting from 1
    for index, ship in enumerate(ship_list.select('li'), 1):
        ship_string = ship.text

        ship_parts = re.split(r' - | -', ship_string)

        name = ship_parts[0]

        character_string = ship_parts[1].split(', ')
        characters_all = character_string[0].split(' & ')
        character1 = characters_all[0]
        character2 = characters_all[1]

        show = character_string[1]

        year = link[-4:]

        ship_info = {
            'year': year,
            'rank': index,
            'name': name,
            'character 1': character1,
            'character 2': character2,
            'show': show,
        }

        ships.append(ship_info)

    all_ships.extend(ships)

# %%
df = pd.DataFrame(all_ships)
df
# Out:
#     year  rank             name       character 1         character 2  \
# 0   2014     1          Destiel   Dean Winchester             Castiel
# 1   2014     2         Johnlock       John Watson     Sherlock Holmes
# 2   2014     3  Larry Stylinson      Harry Styles     Louis Tomlinson
# 3   2014     4     Captain Swan      Captain Hook           Emma Swan
# 4   2014     5            Ereri       Eren Jaeger       Levi Ackerman
# 5   2014     6           Sterek  Stiles Stilinski          Derek Hale
# 6   2014     7          Troyler       Troye Sivan        Tyler Oakley
# 7   2014     8         MakoHaru  Makoto Tachibana       Haruka Nanase
# 8   2014     9            Narry      Harry Styles         Niall Horan
# 9   2014    10        JeanMarco     Jean Kirstein          Marco Bott
# 10  2014    11          HaruRin     Haruka Nanase        Rin Matsuoka
# 11  2014    12           Delena   Damon Salvatore       Elena Gilbert
# 12  2014    13           Stydia  Stiles Stilinski        Lydia Martin
# 13  2014    14           Klaine       Kurt Hummel     Blaine Anderson
# 14  2014    15             Ziam        Zayn Malik          Liam Payne
# 15  2014    16            Kimye    Kim Kardashian          Kanye West
# 16  2014    17           Stucky      Steve Rogers        Bucky Barnes
# 17  2014    18          Olicity      Oliver Queen      Felicity Smoak
# 18  2014    19     Dan and Phil    danisnotonfire         AmazingPhil
# 19  2014    20       Swan Queen      Regina Mills           Emma Swan
# 20  2015     1  Larry Stylinson      Harry Styles     Louis Tomlinson
# 21  2015     2     Dan and Phil        Dan Howell         Phil Lester
# 22  2015     3          Destiel   Dean Winchester             Castiel
# 23  2015     4          Olicity      Oliver Queen      Felicity Smoak
# 24  2015     5     Captain Swan      Captain Hook           Emma Swan
# 25  2015     6        Korrasami      Avatar Korra          Asami Sato
# 26  2015     7         SasuSaku     Sasuke Uchiha       Sakura Haruno
# 27  2015     8            Clexa    Clarke Griffin      Commander Lexa
# 28  2015     9           Stucky      Steve Rogers        Bucky Barnes
# 29  2015    10        Hollstein      Laura Hollis  Carmilla Karnstein
# 30  2015    11         Bellarke     Bellamy Blake      Clarke Griffin
# 31  2015    12         Johnlock       John Watson     Sherlock Holmes
# 32  2015    13               J2     Jensen Ackles     Jared Padalecki
# 33  2015    14       Swan Queen      Regina Mills           Emma Swan
# 34  2015    15            Ereri       Eren Jaeger       Levi Ackerman
# 35  2015    16           Sterek  Stiles Stilinski          Derek Hale
# 36  2015    17         NaruHina    Naruto Uzumaki        Hinata Hyüga
# 37  2015    18             Ziam        Zayn Malik          Liam Payne
# 38  2015    19            Narry       Niall Horan        Harry Styles
# 39  2015    20           Klaine       Kurt Hummel     Blaine Anderson
#
#                                    show
# 0                          Supernatural
# 1                              Sherlock
# 2                         One Direction
# 3                      Once Upon a Time
# 4                       Attack on Titan
# 5                             Teen Wolf
# 6                             YouTubers
# 7                                 Free!
# 8                         One Direction
# 9                       Attack on Titan
# 10                                Free!
# 11                  The Vampire Diaries
# 12                            Teen Wolf
# 13                                 Glee
# 14                        One Direction
# 15                America’s Sweethearts
# 16  Captain America: The Winter Soldier
# 17                                Arrow
# 18                            YouTubers
# 19                     Once Upon a Time
# 20                        One Direction
# 21                            YouTubers
# 22                         Supernatural
# 23                                Arrow
# 24                     Once Upon a Time
# 25                  The Legend of Korra
# 26                               Naruto
# 27                              The 100
# 28           Captain America: Civil War
# 29                             Carmilla
# 30                              The 100
# 31                             Sherlock
# 32            When Brothers Become BFFs
# 33                     Once Upon a Time
# 34                      Attack on Titan
# 35                            Teen Wolf
# 36                               Naruto
# 37                        One Direction
# 38                        One Direction
# 39                                 Glee

# %%
# now do 2021 and 2022

# %%
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020]

ship_ids = {
    2014: 'Most_Reblogged_Ships',
    2015: 'Most_Reblogged_Ships',
    2016: '2016.27s_Top_Ships',
    2017: '2017.27s_Top_Ships',
    2018: '2018.27s_Top_Ships',
    2019: 'Top_100_Ships',
    2020: '100_Ships'
}

all_ships = []

for year in years:
    link = f"https://fanlore.org/wiki/Tumblr_Fandometrics%27_Year_in_Review_{year}"
    response = requests.get(link)
    html = response.text

    soup = BeautifulSoup(html)

    ship_id = ship_ids.get(year)
    ship_list = soup.find('span', id=ship_id).find_next('ol')

    ships = []

    # enumerate starting from 1
    for index, ship in islice(enumerate(ship_list.select('li'), 1), 20):
        ship_string = ship.text

        ship_parts = re.split(r' - | -', ship_string)

        name = ship_parts[0]

        character_string = ship_parts[1].split(', ')
        characters_all = character_string[0].split(' & ')
        character1 = characters_all[0]
        character2 = characters_all[1]

        show_ranked = character_string[1]
        show = re.sub(r'[-+]\d+', '', show_ranked).strip()
                
        year = link[-4:]

        ship_info = {
            'year': year,
            'rank': index,
            'name': name,
            'character 1': character1,
            'character 2': character2,
            'show': show,
        }

        ships.append(ship_info)

    all_ships.extend(ships)

# %%
df = pd.DataFrame(all_ships)
df
# Out:
#      year  rank             name      character 1       character 2  \
# 0    2014     1          Destiel  Dean Winchester           Castiel
# 1    2014     2         Johnlock      John Watson   Sherlock Holmes
# 2    2014     3  Larry Stylinson     Harry Styles   Louis Tomlinson
# 3    2014     4     Captain Swan     Captain Hook         Emma Swan
# 4    2014     5            Ereri      Eren Jaeger     Levi Ackerman
# ..    ...   ...              ...              ...               ...
# 135  2020    16           Drarry     Draco Malfoy      Harry Potter
# 136  2020    17        Gallavich    Ian Gallagher  Mickey Milkovich
# 137  2020    18           Stucky     Steve Rogers      Bucky Barnes
# 138  2020    19           Zutara             Zuko            Katara
# 139  2020    20           Klance            Keith             Lance
#
#                             show
# 0                   Supernatural
# 1                       Sherlock
# 2                  One Direction
# 3               Once Upon a Time
# 4                Attack on Titan
# ..                           ...
# 135    the Harry Potter universe
# 136                    Shameless
# 137          the Marvel universe
# 138   Avatar: The Last Airbender
# 139  Voltron: Legendary Defender
#
# [140 rows x 6 columns]

# %% [markdown]
# # 2013

# %%
link = "https://fandom.tumblr.com/post/162440709774/most-reblogged-ships-of-2013-makoharu-nanase"
response = requests.get(link)
html = response.text

soup = BeautifulSoup(html)

# %%
ships_2013 = soup.find('figcaption').find_next("ol")

ships_2013.select('li')[0]

name = ships_2013.select('li')[0].find("a").text
# MakoHaru

characters_info = ships_2013.select('li')[0].contents[2].strip().split(' & ')
characters = [character.strip().replace(',', '') for character in characters_info]
# ['Nanase Haruka', 'Tachibana Makoto']

show = ships_2013.select('li')[0].contents[3].text
# Free!

# %%
ships_2013_info = []

for index, ship in islice(enumerate(ships_2013.select('li'), 1), 20):
    name = ship.find("a").text

    characters_info = ship.contents[2].strip().split(' & ')
    characters = [character.strip().replace(',', '') for character in characters_info]
    character1 = characters[0]
    character2 = characters[1]

    show = ship.contents[3].text

    ships_info = {
            'year': 2013,
            'rank': index,
            'name': name,
            'character 1': character1,
            'character 2': character2,
            'show': show,
        }
    
    ships_2013_info.append(ships_info)
    
all_ships.extend(ships_2013_info)

# %%
ships_2013_info
df_2013 = pd.DataFrame(ships_2013_info)

merged_df = pd.concat([df, df_2013], axis=0)

merged_df_final = merged_df.sort_values(by=['year', 'rank'], ascending=True)
merged_df_final
# Out:
#      year  rank             name      character 1       character 2  \
# 0    2013     1         MakoHaru    Nanase Haruka  Tachibana Makoto
# 1    2013     2               J2  Jared Padalecki     Jensen Ackles
# 2    2013     3  Larry Stylinson     Harry Styles   Louis Tomlinson
# 3    2013     4          Destiel  Dean Winchester           Castiel
# 4    2013     5         Johnlock      John Watson          Sherlock
# ..    ...   ...              ...              ...               ...
# 135  2020    16           Drarry     Draco Malfoy      Harry Potter
# 136  2020    17        Gallavich    Ian Gallagher  Mickey Milkovich
# 137  2020    18           Stucky     Steve Rogers      Bucky Barnes
# 138  2020    19           Zutara             Zuko            Katara
# 139  2020    20           Klance            Keith             Lance
#
#                             show
# 0                          Free!
# 1                         actors
# 2                  One Direction
# 3                   Supernatural
# 4                       Sherlock
# ..                           ...
# 135    the Harry Potter universe
# 136                    Shameless
# 137          the Marvel universe
# 138   Avatar: The Last Airbender
# 139  Voltron: Legendary Defender
#
# [160 rows x 6 columns]

# %% [markdown]
# # 2021

# %%
link = "https://fanlore.org/wiki/Tumblr%E2%80%99s_Year_in_Review_2021"
response = requests.get(link)
html = response.text

soup = BeautifulSoup(html)

ships_2021 = soup.find('span', id='Ships').find_next('ol')

# %%
ships_2021_info = []

for index, ship in enumerate(ships_2021.select('li'), 1):
    ship_string = ship.text

    ship_parts = re.split(r' - | -', ship_string)

    name = ship_parts[0]

    character_string = ship_parts[1].split(', ')
    characters_all = character_string[0].split(' & ')
    character1 = characters_all[0]
    character2 = characters_all[1]

    show = character_string[1]
    show = re.sub(r'\+\d+', '', show)

    year = link[-4:]

    ship_info = {
        'year': year,
        'rank': index,
        'name': name,
        'character 1': character1,
        'character 2': character2,
        'show': show,
    }

    ships_2021_info.append(ship_info)

all_ships.extend(ships_2021_info)

# %%
df_2021 = pd.DataFrame(ships_2021_info)

merged_df = pd.concat([merged_df, df_2021], axis=0)

merged_df_final = merged_df.sort_values(by=['year', 'rank'], ascending=True)
merged_df_final
# Out:
#     year  rank             name      character 1       character 2  \
# 0   2013     1         MakoHaru    Nanase Haruka  Tachibana Makoto
# 1   2013     2               J2  Jared Padalecki     Jensen Ackles
# 2   2013     3  Larry Stylinson     Harry Styles   Louis Tomlinson
# 3   2013     4          Destiel  Dean Winchester           Castiel
# 4   2013     5         Johnlock      John Watson          Sherlock
# ..   ...   ...              ...              ...               ...
# 15  2021    16            Zukka             Zuko             Sokka
# 16  2021    17         Bumbleby   Yang Xiao Long  Blake Belladonna
# 17  2021    18        Jonmartin    Jonathan Sims  Martin Blackwood
# 18  2021    19        Gallavich    Ian Gallagher  Mickey Milkovich
# 19  2021    20        Geraskier  Geralt of Rivia           Jaskier
#
#                           show
# 0                        Free!
# 1                       actors
# 2                One Direction
# 3                 Supernatural
# 4                     Sherlock
# ..                         ...
# 15  Avatar: The Last Airbender
# 16                        RWBY
# 17         The Magnus Archives
# 18                   Shameless
# 19                The Witcher
#
# [180 rows x 6 columns]

# %% [markdown]
# # 2022

# %%
link = "https://fandom.tumblr.com/post/702448526072987648/ships-if-its-not-canon-at-least-theres-always"
response = requests.get(link)
html = response.text

soup = BeautifulSoup(html)

ships_2022 = soup.find('figcaption').find_next("ol")

# %%
ships_2022 = soup.find('figcaption').find_next("ol")

ships_2022.select('li')[0]

name = ships_2022.select('li')[0].find("a").text
# MakoHaru

characters_info = ships_2022.select('li')[0].contents[1].strip()
characters_info = re.split(' &amp; | & ', characters_info)
characters = [character.strip().replace(',', '') for character in characters_info]
print(ships_2022.select('li')[2].contents[-2])

# show = ships_2022.select('li')[0].contents[2].text

# ships_2022
# Out:
# Dean Winchester & Castiel,

# %%
ships_2022_info = []

for index, ship in islice(enumerate(ships_2022.select('li'), 1), 20):
    name = ship.find("a").text

    characters_info = ship.contents[-2].strip().split(' & ')
    characters = [character.strip().replace(',', '') for character in characters_info]
    character1 = characters[0]
    character2 = characters[1]

    show = ship.contents[-1].text

    ships_info = {
            'year': 2022,
            'rank': index,
            'name': name,
            'character 1': character1,
            'character 2': character2,
            'show': show,
        }
    
    ships_2022_info.append(ships_info)
    
all_ships.extend(ships_2022_info)

# %%
df_2022 = pd.DataFrame(ships_2022_info)

merged_df = pd.concat([merged_df, df_2022], axis=0)

merged_df_final = merged_df.sort_values(by=['year', 'rank'], ascending=True)
merged_df_final
# Out:
#     year  rank             name      character 1       character 2  \
# 0   2013     1         MakoHaru    Nanase Haruka  Tachibana Makoto
# 1   2013     2               J2  Jared Padalecki     Jensen Ackles
# 2   2013     3  Larry Stylinson     Harry Styles   Louis Tomlinson
# 3   2013     4          Destiel  Dean Winchester           Castiel
# 4   2013     5         Johnlock      John Watson          Sherlock
# ..   ...   ...              ...              ...               ...
# 15  2021    16            Zukka             Zuko             Sokka
# 16  2021    17         Bumbleby   Yang Xiao Long  Blake Belladonna
# 17  2021    18        Jonmartin    Jonathan Sims  Martin Blackwood
# 18  2021    19        Gallavich    Ian Gallagher  Mickey Milkovich
# 19  2021    20        Geraskier  Geralt of Rivia           Jaskier
#
#                           show
# 0                        Free!
# 1                       actors
# 2                One Direction
# 3                 Supernatural
# 4                     Sherlock
# ..                         ...
# 15  Avatar: The Last Airbender
# 16                        RWBY
# 17         The Magnus Archives
# 18                   Shameless
# 19                The Witcher
#
# [320 rows x 6 columns]

# %%
merged_df_final.to_csv('ships.csv', index=False, encoding='utf-8')

# %%
# Out:
# Hannibal
# the Marvel universe
# Supergirl
# 9-1-1
